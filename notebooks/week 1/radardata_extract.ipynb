# %%
from scipy.io import readsav
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import glob
import pandas as pd

# %% [markdown]
# # Read radar auxiliary data

# %%
lat_dict = readsav(r"../../data/auxiliary/radar_lat.sav")
lon_dict = readsav(r"../../data/auxiliary/radar_lon.sav")
inci_dict = readsav(r"../../data/auxiliary/inci_arr.sav")
mask_dict = readsav(r"../../data/auxiliary/radar_mask.sav")

# %% [markdown]
# # Find indixes for three station coordinates

# %% [markdown]
# # Loop over radar images to extract features
